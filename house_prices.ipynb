# %%
from __future__ import division, print_function
# отключим всякие предупреждения Anaconda
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
train_df = pd.read_csv('../../data/train.csv')
test_df = pd.read_csv('../../data/test.csv')

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
train_df.shape
# Out:
# (1460, 81)

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
y_train= train_df['SalePrice']

# %%
train_df.drop(['SalePrice'], axis=1, inplace=True)

# %%
X_train = train_df

# %%
X_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub      ...                 0        0    NaN   NaN
# 1         Lvl    AllPub      ...                 0        0    NaN   NaN
# 2         Lvl    AllPub      ...                 0        0    NaN   NaN
# 3         Lvl    AllPub      ...                 0        0    NaN   NaN
# 4         Lvl    AllPub      ...                 0        0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
X_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC Fence  \
# 0         Lvl    AllPub      ...                 0        0    NaN   NaN
# 1         Lvl    AllPub      ...                 0        0    NaN   NaN
# 2         Lvl    AllPub      ...                 0        0    NaN   NaN
# 3         Lvl    AllPub      ...                 0        0    NaN   NaN
# 4         Lvl    AllPub      ...                 0        0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
all_data=X_train

# %%
all_data["PoolQC"] = all_data["PoolQC"].fillna("None")
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")
all_data["Alley"] = all_data["Alley"].fillna("None")
all_data["Fence"] = all_data["Fence"].fillna("None")
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])
all_data["Functional"] = all_data["Functional"].fillna("Typ")
all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])
all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

# %%
X_train=all_data

# %%
X_train.shape
# Out:
# (1460, 80)

# %%
all_data=test_df

# %%
all_data["PoolQC"] = all_data["PoolQC"].fillna("None")
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")
all_data["Alley"] = all_data["Alley"].fillna("None")
all_data["Fence"] = all_data["Fence"].fillna("None")
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])
all_data["Functional"] = all_data["Functional"].fillna("Typ")
all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])
all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])
all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

# %%
test_df=all_data

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
X_train = pd.concat([X_train, 
                  pd.get_dummies(X_train['MSSubClass'], prefix="MSSubClass"),
                  pd.get_dummies(X_train['MSZoning'], prefix="MSZoning"),
                  pd.get_dummies(X_train['Street'], prefix="Street"),
                    pd.get_dummies(X_train['Alley'], prefix="Alley"),
                     pd.get_dummies(X_train['LotShape'], prefix="LotShape"),
                     pd.get_dummies(X_train['LandContour'], prefix="LandContour"),
                     pd.get_dummies(X_train['Utilities'], prefix="Utilities"),
                     pd.get_dummies(X_train['LandSlope'], prefix="LandSlope"),
                     pd.get_dummies(X_train['LotConfig'], prefix="LotConfig"),
                     pd.get_dummies(X_train['Neighborhood'], prefix="Neighborhood"),
                     pd.get_dummies(X_train['Condition1'], prefix="Condition1"),
                     pd.get_dummies(X_train['Condition2'], prefix="Condition2"),
                     pd.get_dummies(X_train['BldgType'], prefix="BldgType"),
                     pd.get_dummies(X_train['HouseStyle'], prefix="HouseStyle"),
                     pd.get_dummies(X_train['OverallQual'], prefix="OverallQual"),
                     pd.get_dummies(X_train['OverallCond'], prefix="OverallCond"),
                     pd.get_dummies(X_train['RoofStyle'], prefix="RoofStyle"),
                     pd.get_dummies(X_train['RoofMatl'], prefix="RoofMatl"),
                     pd.get_dummies(X_train['Exterior1st'], prefix="Exterior1st"),
                     pd.get_dummies(X_train['Exterior2nd'], prefix="Exterior2nd"),
                     pd.get_dummies(X_train['MasVnrType'], prefix="MasVnrType"),
                     pd.get_dummies(X_train['ExterQual'], prefix="ExterQual"),
                     pd.get_dummies(X_train['ExterCond'], prefix="ExterCond"),
                     pd.get_dummies(X_train['Foundation'], prefix="Foundation"),
                     pd.get_dummies(X_train['BsmtQual'], prefix="BsmtQual"),
                     pd.get_dummies(X_train['BsmtCond'], prefix="BsmtCond"),
                     pd.get_dummies(X_train['BsmtExposure'], prefix="BsmtExposure"),
                     pd.get_dummies(X_train['BsmtFinType1'], prefix="BsmtFinType1"),
                     pd.get_dummies(X_train['BsmtFinType2'], prefix="BsmtFinType2"),
                     pd.get_dummies(X_train['Heating'], prefix="Heating"),
                     pd.get_dummies(X_train['HeatingQC'], prefix="HeatingQC"),
                     pd.get_dummies(X_train['CentralAir'], prefix="CentralAir"),
                     pd.get_dummies(X_train['Electrical'], prefix="Electrical"),
                     pd.get_dummies(X_train['KitchenQual'], prefix="KitchenQual"),
                     pd.get_dummies(X_train['Functional'], prefix="Functional"),
                     pd.get_dummies(X_train['FireplaceQu'], prefix="FireplaceQu"),
                     pd.get_dummies(X_train['GarageType'], prefix="GarageType"),
                     pd.get_dummies(X_train['GarageFinish'], prefix="GarageFinish"),
                     pd.get_dummies(X_train['GarageQual'], prefix="GarageQual"),
                     pd.get_dummies(X_train['GarageCond'], prefix="GarageCond"),
                     pd.get_dummies(X_train['PavedDrive'], prefix="PavedDrive"),
                     pd.get_dummies(X_train['PoolQC'], prefix="PoolQC"),
                     pd.get_dummies(X_train['Fence'], prefix="Fence"),
                     pd.get_dummies(X_train['SaleType'], prefix="SaleType"),
                     pd.get_dummies(X_train['SaleCondition'], prefix="SaleCondition"),
                     pd.get_dummies(X_train['MiscFeature'], prefix="MiscFeature"), 
                 ], axis=1)

# %%
X_train.shape
# Out:
# (1460, 380)

# %%
X_train.drop(['MSSubClass','MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LandSlope', 'LotConfig', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'SaleType', 'SaleCondition', 'Id', 'MiscFeature'], axis=1, inplace=True)

# %%
X_train.shape
# Out:
# (1460, 333)

# %%
logit = LinearRegression()

# %%
logit.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
round(logit.score(X_train, y_train), 3)
# Out:
# 0.938

# %%
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave  None      Reg
# 1  1462          20       RL         81.0    14267   Pave  None      IR1
# 2  1463          60       RL         74.0    13830   Pave  None      IR1
# 3  1464          60       RL         78.0     9978   Pave  None      IR1
# 4  1465         120       RL         43.0     5005   Pave  None      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0   None  MnPrv
# 1         Lvl    AllPub      ...                 0        0   None   None
# 2         Lvl    AllPub      ...                 0        0   None  MnPrv
# 3         Lvl    AllPub      ...                 0        0   None   None
# 4         HLS    AllPub      ...               144        0   None   None
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
test_df = pd.concat([test_df, 
                  pd.get_dummies(test_df['MSSubClass'], prefix="MSSubClass"),
                  pd.get_dummies(test_df['MSZoning'], prefix="MSZoning"),
                  pd.get_dummies(test_df['Street'], prefix="Street"),
                    pd.get_dummies(test_df['Alley'], prefix="Alley"),
                     pd.get_dummies(test_df['LotShape'], prefix="LotShape"),
                     pd.get_dummies(test_df['LandContour'], prefix="LandContour"),
                     pd.get_dummies(test_df['Utilities'], prefix="Utilities"),
                     pd.get_dummies(test_df['LandSlope'], prefix="LandSlope"),
                     pd.get_dummies(test_df['LotConfig'], prefix="LotConfig"),
                     pd.get_dummies(test_df['Neighborhood'], prefix="Neighborhood"),
                     pd.get_dummies(test_df['Condition1'], prefix="Condition1"),
                     pd.get_dummies(test_df['Condition2'], prefix="Condition2"),
                     pd.get_dummies(test_df['BldgType'], prefix="BldgType"),
                     pd.get_dummies(test_df['HouseStyle'], prefix="HouseStyle"),
                     pd.get_dummies(test_df['OverallQual'], prefix="OverallQual"),
                     pd.get_dummies(test_df['OverallCond'], prefix="OverallCond"),
                     pd.get_dummies(test_df['RoofStyle'], prefix="RoofStyle"),
                     pd.get_dummies(test_df['RoofMatl'], prefix="RoofMatl"),
                     pd.get_dummies(test_df['Exterior1st'], prefix="Exterior1st"),
                     pd.get_dummies(test_df['Exterior2nd'], prefix="Exterior2nd"),
                     pd.get_dummies(test_df['MasVnrType'], prefix="MasVnrType"),
                     pd.get_dummies(test_df['ExterQual'], prefix="ExterQual"),
                     pd.get_dummies(test_df['ExterCond'], prefix="ExterCond"),
                     pd.get_dummies(test_df['Foundation'], prefix="Foundation"),
                     pd.get_dummies(test_df['BsmtQual'], prefix="BsmtQual"),
                     pd.get_dummies(test_df['BsmtCond'], prefix="BsmtCond"),
                     pd.get_dummies(test_df['BsmtExposure'], prefix="BsmtExposure"),
                     pd.get_dummies(test_df['BsmtFinType1'], prefix="BsmtFinType1"),
                     pd.get_dummies(test_df['BsmtFinType2'], prefix="BsmtFinType2"),
                     pd.get_dummies(test_df['Heating'], prefix="Heating"),
                     pd.get_dummies(test_df['HeatingQC'], prefix="HeatingQC"),
                     pd.get_dummies(test_df['CentralAir'], prefix="CentralAir"),
                     pd.get_dummies(test_df['Electrical'], prefix="Electrical"),
                     pd.get_dummies(test_df['KitchenQual'], prefix="KitchenQual"),
                     pd.get_dummies(test_df['Functional'], prefix="Functional"),
                     pd.get_dummies(test_df['FireplaceQu'], prefix="FireplaceQu"),
                     pd.get_dummies(test_df['GarageType'], prefix="GarageType"),
                     pd.get_dummies(test_df['GarageFinish'], prefix="GarageFinish"),
                     pd.get_dummies(test_df['GarageQual'], prefix="GarageQual"),
                     pd.get_dummies(test_df['GarageCond'], prefix="GarageCond"),
                     pd.get_dummies(test_df['PavedDrive'], prefix="PavedDrive"),
                     pd.get_dummies(test_df['PoolQC'], prefix="PoolQC"),
                     pd.get_dummies(test_df['Fence'], prefix="Fence"),
                     pd.get_dummies(test_df['SaleType'], prefix="SaleType"),
                     pd.get_dummies(test_df['SaleCondition'], prefix="SaleCondition"),
                     pd.get_dummies(test_df['MiscFeature'], prefix="MiscFeature"), 
                 ], axis=1)

# %%
test_df.shape
# Out:
# (1459, 363)

# %%
test_df.drop(['MSSubClass','MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LandSlope', 'LotConfig', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'SaleType', 'SaleCondition', 'Id', 'MiscFeature'], axis=1, inplace=True)

# %%
test_df.shape
# Out:
# (1459, 316)

# %%
final_train, final_test = train_df.align(test_df, axis=1)

# %%
final_train.shape
# Out:
# (1460, 363)

# %%
final_test.shape
# Out:
# (1459, 363)

# %%
prediction = logit.predict(final_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-bdd29d3276fb> in <module>()
# ----> 1 prediction = logit.predict(final_test)
#
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     237         check_is_fitted(self, "coef_")
#     238
# --> 239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
#     241                                dense_output=True) + self.intercept_
#
# ...

# %%
test_df.shape

# %%
X_train.shape

# %%
test_df.head()

# %%
list(X_train.columns.values)

# %%
list(test_df.columns.values)
